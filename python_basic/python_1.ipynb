# %% [markdown]
# <a href="https://colab.research.google.com/github/mdmostafizurrahman6351/python_prigrming/blob/main/python_basic/python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = "data science is fun"
data
# Out:
# 'data science is fun'

# %%
data = input()
# Out:
# data csience is fun

# %%
type(data) # type function is seclect data type
# Out:
# str

# %%
x = input() # input function is defolt input string vlue
y = input()
x + y
# Out:
# 23
# 34
# '2334'

# %%
type(x)
# Out:
# str

# %%
x = int(input("enter your 1st nimber: "))
y = int(input("enter your 2nd nimber: "))
result = x + y
result
# Out:
# enter your 1st nimber: 23
# enter your 2nd nimber: 67
# 90

# %%
data = "data science is fun, is science"
data
# Out:
# 'data science is fun, is science'

# %%
import sys
sys.getsizeof(data) # getsizeof function is define data save mamory
# Out:
# 60

# %%
data.count("is") #count function is counted value in list
# Out:
# 2

# %%
data.find("is") # find function is finded data index in list
# Out:
# 13

# %%
data.find("my") # if null value return -1
# Out:
# -1

# %%
data.index("s")
# Out:
# 5

# %%
# data.index("s",6,10) # if index is rong so code error

# %%
data.find("s",6,9)
# Out:
# -1

# %%
data = "data Sience Is Fun"
data.lower() # lower function is all cher lower
# Out:
# 'data sience is fun'

# %%
data.upper() # upper function is all cher upper
# Out:
# 'DATA SIENCE IS FUN'

# %%
data.casefold() # casefold function is all cher is lower
# Out:
# 'data sience is fun'

# %%
data.capitalize() # capitalizer function is fast word upper and another cher lower
# Out:
# 'Data sience is fun'

# %%
data.swapcase() # swapcas function is lower to upper and upper to lower
# Out:
# 'DATA sIENCE iS fUN'

# %%
data.title() # title function is every word in fast word upper , another cher is lower
# Out:
# 'Data Sience Is Fun'

# %%
data.islower() # islower function is check all cher lower
# Out:
# False

# %%
data.isupper() # isupper function is check all cher upper
# Out:
# False

# %%
data.isdigit() # isdigit function is check all xher is digit
# Out:
# False

# %%
data.encode() # encode function os data convart byte
# Out:
# b'data Sience Is Fun'

# %%
type(data.encode())
# Out:
# bytes

# %%
data.split() # split function is all word separate dubbel cutation and comma and creat list
# Out:
# ['data', 'Sience', 'Is', 'Fun']
