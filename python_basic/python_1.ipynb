# %%
data = "data science is fun"
data
# Out:
# 'data science is fun'

# %%
data = input()
# Out:
# data csience is fun

# %%
type(data)
# Out:
# str

# %%
x = input()
y = input()
x + y
# Out:
# 23
# 34
# '2334'

# %%
type(x)
# Out:
# str

# %%
x = int(input("enter your 1st nimber: "))
y = int(input("enter your 2nd nimber: "))
result = x + y
result
# Out:
# enter your 1st nimber: 23
# enter your 2nd nimber: 67
# 90

# %%
data = "data science is fun, is science"
data
# Out:
# 'data science is fun, is science'

# %%
import sys
sys.getsizeof(data)
# Out:
# 60

# %%
data.count("is")
# Out:
# 2

# %%
data.find("is")
# Out:
# 13

# %%
data.find("my")
# Out:
# -1

# %%
data.index("s")
# Out:
# 5

# %%
data.index("s",6,10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2983009776.py in <cell line: 0>()
# ----> 1 data.index("s",6,10)
#
# ValueError: substring not found

# %%
data.find("s",6,9)
# Out:
# -1

# %%
data = "data Sience Is Fun"
data.lower()
# Out:
# 'data sience is fun'

# %%
data.upper()
# Out:
# 'DATA SIENCE IS FUN'

# %%
data.casefold()
# Out:
# 'data sience is fun'

# %%
data.capitalize()
# Out:
# 'Data sience is fun'

# %%
data.swapcase()
# Out:
# 'DATA sIENCE iS fUN'

# %%
data.title()
# Out:
# 'Data Sience Is Fun'

# %%
data.islower()
# Out:
# False

# %%
data.isupper()
# Out:
# False

# %%
data.isdigit()
# Out:
# False

# %%
data.encode()
# Out:
# b'data Sience Is Fun'

# %%
type(data.encode())
# Out:
# bytes

# %%
data.split()
# Out:
# ['data', 'Sience', 'Is', 'Fun']
